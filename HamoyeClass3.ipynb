# %% [markdown]
# <a href="https://colab.research.google.com/github/sobiyeo/iExcel/blob/main/HamoyeClass3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv("hotel_bookings.csv")

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# Note that using new_var = var.dropna(implace = true). will make permanent changes in the dataset in Pandas

# %% [markdown]
# Cleaning Null Values

# %% [markdown]
# Dropping the company column which has the highest number of null

# %%
df2 = df.drop(["company"], axis = 1)

# %% [markdown]
# checking

# %%
df2.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.shape
# Out:
# (119390, 32)

# %%
df2.shape
# Out:
# (119390, 31)

# %% [markdown]
# Dropping all other null values and checking for shape

# %%
df2.dropna().shape
# Out:
# (102894, 31)

# %%
df2.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
df2.dropna(inplace = True)

# %% [markdown]
# SPLITTING DATASET INTO NUMERICAL AND CATEGORICAL GROUPS

# %%
numerical_df = df2.select_dtypes(include = [int, float])

# %%
numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102894 entries, 3 to 119389
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   is_canceled                     102894 non-null  int64
#  1   lead_time                       102894 non-null  int64
#  2   arrival_date_year               102894 non-null  int64
#  3   arrival_date_week_number        102894 non-null  int64
#  4   arrival_date_day_of_month       102894 non-null  int64
#  5   stays_in_weekend_nights         102894 non-null  int64
#  6   stays_in_week_nights            102894 non-null  int64
#  7   adults                          102894 non-null  int64
#  8   children                        102894 non-null  float64
#  9   babies                          102894 non-null  int64
#  10  is_repeated_guest               102894 non-null  int64
#  11  previous_cancellations          102894 non-null  int64
# ...

# %%
cat_df = df.select_dtypes(exclude = [int, float])

# %%
cat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   hotel                    119390 non-null  object
#  1   arrival_date_month       119390 non-null  object
#  2   meal                     119390 non-null  object
#  3   country                  118902 non-null  object
#  4   market_segment           119390 non-null  object
#  5   distribution_channel     119390 non-null  object
#  6   reserved_room_type       119390 non-null  object
#  7   assigned_room_type       119390 non-null  object
#  8   deposit_type             119390 non-null  object
#  9   customer_type            119390 non-null  object
#  10  reservation_status       119390 non-null  object
#  11  reservation_status_date  119390 non-null  object
# dtypes: object(12)
# memory usage: 10.9+ MB

# %% [markdown]
# #Categorical EDA

# %%
cat_df.describe()
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status reservation_status_date
# count        119390        119390             119390                  119390
# unique            3             4                  3                     926
# ...

# %% [markdown]
# Using Seaborn

# %%
sns.countplot(cat_df, x = "hotel")
# Out:
# <Axes: xlabel='hotel', ylabel='count'>

# %%
sns.countplot(cat_df, x = "market_segment")
# Out:
# <Axes: xlabel='market_segment', ylabel='count'>

# %%
cat_df["customer_type"].value_counts()
# Out:
# Transient          89613
# Transient-Party    25124
# Contract            4076
# Group                577
# Name: customer_type, dtype: int64

# %% [markdown]
# Plotting the above into a pie chart

# %%
cat_df["customer_type"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='customer_type'>

# %% [markdown]
# NUMERICAL DATA THAT ARE CATEGORICAL IN NATURE

# %%
sns.countplot(numerical_df, x = "is_canceled")
# Out:
# <Axes: xlabel='is_canceled', ylabel='count'>

# %%
numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102894 entries, 3 to 119389
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   is_canceled                     102894 non-null  int64
#  1   lead_time                       102894 non-null  int64
#  2   arrival_date_year               102894 non-null  int64
#  3   arrival_date_week_number        102894 non-null  int64
#  4   arrival_date_day_of_month       102894 non-null  int64
#  5   stays_in_weekend_nights         102894 non-null  int64
#  6   stays_in_week_nights            102894 non-null  int64
#  7   adults                          102894 non-null  int64
#  8   children                        102894 non-null  float64
#  9   babies                          102894 non-null  int64
#  10  is_repeated_guest               102894 non-null  int64
#  11  previous_cancellations          102894 non-null  int64
# ...

# %% [markdown]
# #Numerical EDA

# %% [markdown]
# Correlation

# %%
numerical_df.corr()
# Out:
#                                 is_canceled  lead_time  arrival_date_year  \
# is_canceled                        1.000000   0.277666           0.004561
# lead_time                          0.277666   1.000000           0.041082
# arrival_date_year                  0.004561   0.041082           1.000000
# arrival_date_week_number           0.004172   0.120155          -0.530387
# arrival_date_day_of_month         -0.005468  -0.003472           0.005206
# stays_in_weekend_nights           -0.023589   0.047674           0.020693
# stays_in_week_nights               0.003918   0.124195           0.032807
# adults                             0.037057   0.072477           0.061359
# children                           0.005409  -0.049796           0.065394
# babies                            -0.032038  -0.021975          -0.009828
# is_repeated_guest                 -0.029913  -0.055432          -0.022428
# previous_cancellations             0.117983   0.100271          -0.134031
# ...

# %% [markdown]
# USING VISUALISATION

# %%
sns.heatmap(numerical_df.corr())
# Out:
# <Axes: >

# %%
plt.scatter(x = range (numerical_df.shape[0]), y= numerical_df["adr"])

# %%
sns.displot(numerical_df["adr"])

# %% [markdown]
# REMOVING OUTLIERS

# %%
numerical_df[numerical_df['adr']> 5000]
# Out:
#        is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 48515            1         35               2016                        13
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 48515                         25                        0
#
#        stays_in_week_nights  adults  children  babies  is_repeated_guest  \
# 48515                     1       2       0.0       0                  0
#
#        previous_cancellations  previous_bookings_not_canceled  \
# 48515                       0                               0
#
#        booking_changes  agent  days_in_waiting_list     adr  \
# 48515                1   12.0                     0  5400.0
#
#        required_car_parking_spaces  total_of_special_requests
# 48515                            0                          0

# %% [markdown]
# creating another dataframe for values below 5000

# %%
less = numerical_df[numerical_df['adr']<5000]

# %%
sns.displot(less["adr"])
